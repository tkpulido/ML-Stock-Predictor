# %%
from app import *
from datapoller import *

# %%
train_and_plot("KO")
# Out:
# Coefficients:
#  [[ 0.99259367  0.22365737 -0.05700577]]
# 0.9701457956546625

# %%
train_and_plot("MSFT")
# Out:
# Coefficients:
#  [[1.00208797 1.3338978  0.01948677]]
# 0.8518120507529665

# %%
train_and_plot("NVDA")
# Out:
# Coefficients:
#  [[0.99827329 3.73139116 0.01420745]]
# 0.8030400702411319

# %%
train_and_plot("GOOG")
# Out:
# Coefficients:
#  [[1.00044587e+00 9.52309188e+00 7.10623862e-03]]
# 0.8206902132418108

# %%
train_and_plot("TSLA")
# Out:
# Coefficients:
#  [[ 1.00099089  9.11020417 -0.01670075]]
# 0.6761696953249949
